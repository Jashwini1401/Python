# %% [markdown]
# #1. Explain the key features of python that make it a popular choice for programming.
#
# ANS:-The key features of python that make it a popular choice for programming:-
#
#      (a)widely used in the Data industry
#      (b)A lot of libraries
#      (c)Fronted and backend data analysis
#      (d)Automation
#      (e)Image processing
#      (f)Databases
#      (g)Ease of learning
#      (h)Versatility
#      (i)Easy to Read
#      (j)Huge active community

# %% [markdown]
#   # 2. Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#
# ANS:-Keywords are reserved words in Python that have special meanings and cannot be used as identifiers (variable names, function names, etc.).They are case-sensitive and cannot be redefined or overridden within a Python program.Examples of keywords include if, else, while, for, def, class, import, try, except, return, True, False, None, etc.Examples:-
#
#      if 3 > 2:
#       print("greater")
#
#      bool(0) - False
#      bool(1) - True

# %% [markdown]
# #3.Compare and contrast mutable and immutable objects in Python with examples.
#
# ANS:- Mutable objects:-Objects/container whose state or value can be changed after they are created are called mutable objects or container. List is a type of mutable object/supports item assignment.Mutability affects how objects are stored and manipulated in memory, impacting performance, memory usage, and concurrency in Python programs. Example:-
#
#      list_cont[1, 2, 3,4.3,(3+5j),True,'Bijay"]
#      list_cont[6] = 'Bijay'
#
# Immutable objects:-Objects/container whose state or value cannot be changed after they are created are called as immutable objects or container. String is a type of immutable objects/ doesn't supports item assignment. Example:-
#
#      b = 'pwskills'
#      If we run this code, we will get-
#      b = 'pwskills'
#      b[0] = 'p'
#      But if we want to change the value of b[0]from P to I,
#      b[0] = 'I'
#      We will get an error because string object does not support item assignment.

# %% [markdown]
# #4. Discuss the different types of operators in Python and provide examples of how they are used.
#
# ANS:-Operators are special symbols or keywords that are used to carry out specific actions on numbers or variables in Python expressions. Operators have precedence and associativity rules that determine the order of evaluation in expressions.Python supports various types of operators, including arithmetic operators (+, -, *, /), comparison operators (==, !=, <, >), logical operators (and, or, not), assignment operators (=, +=, -=, *=, /=), etc.
#
# ###(A)Arithmetic Operators:-Arithmetic operators are used with numeric values to perform common mathematical operations.
#
#        Operator	     Name	         Example	   Evaluation         Answer
#     (a)    +         Addition	        a + b        a=5 ,b=3           8
#     (b)    -	     Subtraction	     a - b	    a=100 ,b=3         97
#     (c)    *	     Multiplication	  a * b	    a=5 ,b=3           15
#     (d)    /	     Division	        a / b        a=21 ,b=4         5.25
#     (e)    %	     Modulus	         a % b	    a=21 ,b=4          1
#     (f)   **	     Exponentiation	  a ** b	   a=2  ,b=5          32
#     (g)   //	     Floor division	  a // b       a=4  ,b=3           1
#
# ###(B)Comparison Operators:-Comparison operators are used to compare two values.
#
#        Operator	  Name	                Example	     Evaluation     Answer
#     (a) ==	      Equal	                a == b	     a=2 ,b=2        True
#     (b) !=	     Not equal	             a != b	     a=3 ,b=3        False
#     (c) >	     Greater than	           a > b	      a=10 ,b=2       True
#     (d) <	      Less than	             a < b	      a=10 ,b=2       False
#     (e) >=	 Greater than or equal to	  a >= b	     a=12 ,b=5       True
#     (f) <=	 Less than or equal to	     a <= b         a=10 ,b=10      True
#
# ###(C)Assignment Operators:-Assignment operators are used to assign values to variables.
#
#        Operator	Example	    Same As	         Evaluation         Answer
#     (a) =	      a = 5	       a = 5               a = 5               5
#     (b) +=	     a += 3	      a = a + 3           a = 5               8
#     (c) -=	     a -= 3	      a = a - 3           a = 5               2
#     (d) *=	     a *= 3	      a = a * 3           a = 5               15
#     (e) /=	     a /= 3	      a = a / 3           a = 15              5
#     (f) %=	     a %= 3	      a = a % 3           a = 16              1
#     (g) //=	    a //= 3	     a = a // 3          a = 25              8
#     (h) **=	    a **= 3	     a = a ** 3          a = 5              125
#     (i) &=	     a &= 3	      a = a & 3           a = 5               1
#     (j) |=	     a |= 3	      a = a | 3           a = 5               7
#     (k) ^=	     a ^= 3	      a = a ^ 3           a = 5               6
#     (l) >>=	    a >>= 3	     a = a >> 3          a = 5               0
#     (m) <<=	    a <<= 3	     a = a << 3          a = 5               40
#     (n) :=	    print(a := 3)	a =3 print(a)       a = 3               3
#
# ###(D)Logical Operators:-Logical operators are used to combine conditional statements.
#
#      Operator	      Example	         Evaluation         Answer
#     (a) and       a > 3 and  a < 10	      a = 5            True
#     (b) or		a > 3 or a < 4	         a = 5            True
#     (c) not       not(a > 3 and a < 10)      a = 5            False
#
# ###(E)Identity Operators:-Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location.
#
#      Operator	 Example	      Evaluation                       Answer
#     (a) is 	   a is b      a = ["apple", "banana"]      print(a is c) = True
#                               b = ["apple", "banana"]      print(a is b) = False
#                               c = a                        print(a == b) = True
#
#
#
#     (b) is not   a is not b  a = ["apple", "banana"]   print(a is not c) = False
#                              b = ["apple", "banana"]   print(a is not b) = True
#                              c = a                     print(a != b) = False
#
# ###(F)Membership Operators:-Membership operators are used to test if a sequence is presented in an object.
#
#       Operator	 Example	        Evaluation                   Answer
#     (a) in 	    a in b	     a = ["apple", "banana"]     print("banana" in a) = True
#     (b) not in    a not in b      a = ["apple", "banana"]     print("pineapple" not in a) = True
#
# ###(G)Bitwise Operators:-Bitwise operators are used to compare (binary) numbers.
#
#        Operator	Name		           Example	        Evalauation      Answer
#     (a) & 	    AND		              a & b	         print(6 & 3)        2
#     (b) |	     OR		               a | b	         print(6 | 3)        7
#     (c) ^         XOR		              a ^ b	         print(6 ^ 3)        5
#     (d) ~	     NOT		               ~a	           print(~3)          -4
#     (e) <<	    Zero fill left shift	 a << 2	        print(3 << 2)      12
#     (f) >>	    Signed right shift	   a >> 2            print(8 >> 2)       2

# %% [markdown]
# #5.Explain the concept of type casting in Python with examples.
#
# ANS:-Type casting, also referred to as type conversion, is the process of changing one data type to another in Python.Type casting is often necessary for performing arithmetic operations, data manipulation and input/output operations in Python programs.Python provides built-in functions for type casting, such as int(), float(), str(), list(), tuple(), dict(), etc.
#
# **Examples of Type Casting in Python:- Mainly type casting can be done with these data type functions:**
#
# **(1) Int():** Python Int() function take float or string as an argument and returns int type object.
#
# **(2)float():** Python float() function take int or string as an argument and return float type object.
#
# **(3)str():** Python str() function takes float or int as an argument and returns string type object.
#
#
# **(A) Python Convert Int to Float**:-
#
#      Python program to demonstrate
#      type Casting
#      int variable
#      a = 5
#      typecast to float
#      n = float(a)
#        print(n)
#        print(type(n))
#
# ###Output:
#      5.0
#     <class 'float'>
#
# **(B)Python Convert Int to String:-**
#
#      Python program to demonstrate
#      type Casting
#      int variable
#      a = 5
#      typecast to str
#      n = str(a)
#       print(n)
#       print(type(n))
#
# ###Output:
#      '5'
#     <class 'str'>
#
# **(C)Python Convert Float to Int:-**
#
#      Python program to demonstrate
#      int variable
#      a = 5.9
#      typecast to int
#      n = int(a)
#       print(n)
#       print(type(n))
#
# ###Output:
#      5
#     <class 'int'>
#
# **(D)Python Convert String to Int:-**
#
#      string variable
#      a = "2"
#      b = 3
#      int (a)+b = 5
#      typecast to int
#      n = int(a)
#       print(n)
#       print(type(n))
#       print(type(int(n)))
#
# ###Output:
#       2
#      <class 'str'>
#      <class 'int'>
#
# **(E)Python Convert String to Float:-**
#
#      Python program to demonstrate
#      type Casting
#      string variable
#      a = "5.9"
#      typecast to float
#      n = float(a)
#       print(n)
#       print(type(n))
#
# ###Output:
#      5.9
#     <class 'float'>
#
#
# **There can be two types of Type Casting in Python:**
#
# **1.Implicit Type Casting**:-In this, method, Python converts the datatype into another datatype automatically. Users don’t have to involve in this process.Example:-
#
#      Python program to demonstrate
#      implicit type Casting
#
#      Python automatically converts
#      a to int
#      a = 7
#      print(type(a))
#
#      Python automatically converts
#      b to float
#      b = 3.0
#      print(type(b))
#
#      Python automatically converts
#      c to float as it is a float addition
#      c = a + b
#      print(c)
#      print(type(c))
#
#      Python automatically converts
#      d to float as it is a float multiplication
#      d = a * b
#      print(d)
#      print(type(d))
#
# ###Output:
#      <class 'int'>
#      <class 'float'>
#      10.0
#      <class 'float'>
#      21.0
#      <class 'float'>
#
#
# **2.Explicit Type Casting**:-In this method, Python needs user involvement to convert the variable data type into the required data type.Example:-
#
#      num_str = "456"
#      num_int = int(num_str)
#
#      print(num_int)
#      print(type(num_int))
# ### Output:
#      456
#     <class 'int'>

# %% [markdown]
# #6. How do conditional statements work in Python? Illustrate with examples.
#
# ANS:-Conditionals in Python are used to execute code based on the evaluation of one or more conditions.Python supports conditional statements such as if, elif (else if), and else to control the flow of execution.Conditionals can be nested to handle multiple conditions and control different branches of execution based on the outcome of logical expressions.
#
# **Types of Conditional Statement in Python**
#
# **1. If Conditional Statement**:-If the simple code of block is to be performed if the condition holds then the if statement is used.
#
# Syntax of If Statement:-
#
#      if condition:
#        # Statements to execute if
#        # condition is true
#
# Example:- # if statement example
#
#      if 10 > 5:
#        print("10 greater than 5")
#        print("Program ended")
#
# ###Output:-
#      10 greater than 5
#      program ended
#
# **2.If else Conditional Statement**:-In a conditional if Statement the additional block of code is merged as an else statement which is performed when if condition is false.
#
# Syntax of If-Else:-
#
#      if (condition):
#        # Executes this block if
#        # condition is true
#      else:
#        # Executes this block if
#        # condition is false
#
# Example:-# if..else statement example
#
#      x = 3
#      if x == 4:
#          print("Yes")
#      else:
#          print("No")
# ###Output:-
#      No
#
# **3.Nested if..else Conditional Statement**:-Nested if..else means an if-else statement inside another if statement. Or in simple words first, there is an outer if statement, and inside it another if - else statement is present and such type of statement is known as nested if statement. We can use one if or else if statement inside another if or else if statements.
#
# Example:-# if..else chain statement example
#
#      letter = "A"
#          if letter == "B":
#             print("letter is B")
#      else:
#          if letter == "C":
#             print("letter is C")
#      else:
#          if letter == "A":
#             print("letter is A")
#      else:
#             print("letter isn't A, B and C")
#
# ###Output:-
#      letter is A
#
# **4.If-elif-else Conditional Statement**:-The if statements are executed from the top down. As soon as one of the conditions controlling the if is true, the statement associated with that if is executed, and the rest of the ladder is bypassed. If none of the conditions is true, then the final “else” statement will be executed.
#
# Example:-# if-elif statement example
#
#      letter = "A"
#        if letter == "B":
#            print("letter is B")
#        elif letter == "C":
#            print("letter is C")
#        elif letter == "A":
#            print("letter is A")
#        else:
#            print("letter isn't A, B or C")
#
# ###Output
#      letter is A

# %% [markdown]
# #7.Describe the different types of loops in Python and their use cases with examples.
#
# Ans:-In Python, loops are employed to repeat a sequence of actions or code until a specific condition is fulfilled.Python offers two primary types of loops: for loops and while loops.“For” loops are used for iterating over a sequence of elements, while “while” loops are used for executing code until a specified condition becomes False.
#
# **The while Loop**:-"While" loops are used for executing code until a speified condition is met.Example:-
#
#      n= 7
#      i = 1
#
#       while i < n:
#         print(i)
#         i += 1
# ###Output:-
#      1
#      2
#      3
#      4
#      5
#      6
#
# **The break Statement**:-With the break statement we can stop the loop even if the while condition is true:Example:-
#
#      n = 7
#      i = 1
#
#      while i < n:
#        print(i)
#        i += 1
#        if i == 3:
#        break
#      else:
#        print("This will be executed when the while is run successfully without any break")
# ###Output:-
#      1
#      2
#
# **The continue Statement**:-With the continue statement we can stop the current iteration, and continue with the next.Example:-
#
#      n = 7
#      i = 1
#
#      while i < n:
#         i += 1
#         if i == 3:
#         continue
#         print(i)
#      else:
#         print("This will be executed when the while is run successfully without any break")
# ###Output:-
#      2
#      4
#      5
#      6
#      7
#      This will be executed when the while is run successfully without any break
#
# **The For Loop**:-A "for" loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).Example:-
#
#      fruits = ["apple", "banana", "cherry"]
#      for x in fruits:
#         print(x)
#
# ###Output:-
#      apple
#      banana
#      cherry
#
# **Looping Through a String**:-Even strings are iterable objects, they contain a sequence of characters.Example:-
#
#      for x in "banana":
#        print(x)
#
# ###Output:-
#        b
#        a
#        n
#        a
#        n
#        a
#
# **The break Statement**:-With the break statement we can stop the loop before it has looped through all the items.Example:-
#
#      fruits = ["apple", "banana", "cherry"]
#      for x in fruits:
#        if x == "banana":
#        break
#        print(x)
#      else:
#        print("This will be executed when a loop ends without a break statement")
#
# ###Output:-
#      apple
#
#
# **The continue Statement**:-With the continue statement we can stop the current iteration of the loop, and continue with the next.Example:-
#
#      fruits = ["apple", "banana", "cherry"]
#      for x in fruits:
#        if x == "banana":
#        continue
#        print(x)
#      else:
#        print("This will be executed when a loop ends without a break statement")
#
# ###Output:-
#      apple
#      cherry
#      This will be executed when a loop ends without a break statement
#
# **The range() Function**:-To loop through a set of code a specified number of times, we can use the range() function.The range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and ends at a specified number.Example:-
#
#       for x in range(2, 6):
#          print(x)
#
# ###Output:-
#      2
#      3
#      4
#      5
